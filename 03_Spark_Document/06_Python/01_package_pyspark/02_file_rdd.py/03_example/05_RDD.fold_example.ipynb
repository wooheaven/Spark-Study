# %%
import findspark
findspark.init()

# %%
import pyspark
sc = pyspark.SparkContext(appName="fold")

# %%
rddA = sc.parallelize([1,2,3,4,5,6,7,8,9],3)
rddA.collect()
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
from operator import add
rddA.fold(zeroValue=0, op=add)
# Out:
# 45

# %%
sum = 0
for num in rddA.collect():
    sum += num
    print(num, sum)
# Out:
# 1 1
# 2 3
# 3 6
# 4 10
# 5 15
# 6 21
# 7 28
# 8 36
# 9 45

# %%
sc.stop()
