# %%
import findspark
findspark.init()

# %%
import pyspark
sc = pyspark.SparkContext(appName="RDD.mean")

# %%
rddA = sc.parallelize([2,4,1])
rddA.collect()
# Out:
# [2, 4, 1]

# %%
rddA.mean()
# Out:
# 2.3333333333333335

# %%
sc.stop()
